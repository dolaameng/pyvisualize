# %% [markdown]
# ### plotting time series data from pd.DataFrame interface
#
# data used is co2 timeseries from R package

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
from zingchart import utils, plots
import pandas as pd
from uuid import uuid4

# %%
co2 = pd.read_csv("data/co2.csv", index_col="time")
co2 = co2.set_index(pd.PeriodIndex(co2.index, freq="M"))

# %%
co2.plot()
